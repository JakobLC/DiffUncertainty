# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helpers import load_result_table
table = load_result_table(swap_AU_EU=True)
print(table.shape)
print(table.columns)
# Out:
# (12, 22)
# Index(['AU', 'EU', 'network', 'version', 'val_dice', 'val_ged', 'val_ged_bma',
#        'id_dice', 'id_ged', 'id_ged_bma', 'AU_ncc', 'EU_ncc', 'TU_ncc',
#        'AU_ace', 'EU_ace', 'TU_ace', 'AU_auc', 'EU_auc', 'TU_auc',
#        '(AU-EU)_ncc', '(EU-AU)_auc', '(min(AU,EU)-TU)_ace'],
#       dtype='object')

# %%
table["EU"]
# Out:
# 0     swag_diag
# 1          swag
# 2       dropout
# 3      ensemble
# 4     swag_diag
# 5          swag
# 6       dropout
# 7      ensemble
# 8     swag_diag
# 9          swag
# 10      dropout
# 11     ensemble
# Name: EU, dtype: object

# %%
max_col_chars = max([len(col) for col in table.columns])
for col in table.columns:
    print(f"{col:{max_col_chars}} : {type(table[col].iloc[0])} ")
# Out:
# AU                  : <class 'str'>
# EU                  : <class 'str'>
# network             : <class 'str'>
# version             : <class 'str'>
# val_dice            : <class 'numpy.float64'>
# val_ged             : <class 'numpy.float64'>
# val_ged_bma         : <class 'numpy.float64'>
# id_dice             : <class 'numpy.float64'>
# id_ged              : <class 'numpy.float64'>
# id_ged_bma          : <class 'numpy.float64'>
# AU_ncc              : <class 'dict'>
# EU_ncc              : <class 'dict'>
# TU_ncc              : <class 'dict'>
# AU_ace              : <class 'dict'>
# EU_ace              : <class 'dict'>
# TU_ace              : <class 'dict'>
# AU_auc              : <class 'dict'>
# EU_auc              : <class 'dict'>
# TU_auc              : <class 'dict'>
# (AU-EU)_ncc         : <class 'dict'>
# (EU-AU)_auc         : <class 'dict'>
# (min(AU,EU)-TU)_ace : <class 'dict'>

# %%
from helpers import plot_metric_matrix

plot_metric_matrix(table,metric="TU_ace",reldiff="(min(AU,EU)-TU)_ace",subkey="ood_noise",cbar_keys=["TU_ace"])

# %%
from helpers import plot_pred_grid, pred_grid_computation
image, batch0 = pred_grid_computation()
plot_pred_grid(image, batch0, 6)
# Out:
# Seed set to 120
# SETTING GLOBAL SEED TO 120
# Dataset: lidc2d id_test - 2790 images
# [SWAG] Sampled 10 model(s) from '/home/jloch/Desktop/diff/luzern/values/saves/lidc64/diffusion_swag/checkpoints/last.ckpt' (n_snapshots=30)
# saving to results dir /home/jloch/Desktop/diff/luzern/values/saves/lidc64/test_results/diffusion_swag/e1000/id
